# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("CocaCola_Sales.csv")

# %%
df
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# ...

# %%
df["t"] = np.arange(1,43)
df["t_squared"] = df["t"]*df["t"]
df.columns
df["log_Sales"] = np.log(df["Sales"])
df.rename(columns={"Sales ": 'Sales'}, inplace=True)
df.Sales.plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#    Quarter        Sales   t  t_squared  log_Sales
# 0    Q1_86  1734.827000   1          1   7.458663
# 1    Q2_86  2244.960999   2          4   7.716443
# 2    Q3_86  2533.804993   3          9   7.837477
# 3    Q4_86  2154.962997   4         16   7.675529
# 4    Q1_87  1547.818996   5         25   7.344602
# 5    Q2_87  2104.411995   6         36   7.651791
# 6    Q3_87  2014.362999   7         49   7.608058
# 7    Q4_87  1991.746998   8         64   7.596767
# 8    Q1_88  1869.049999   9         81   7.533186
# 9    Q2_88  2313.631996  10        100   7.746574
# 10   Q3_88  2128.320000  11        121   7.663088
# 11   Q4_88  2026.828999  12        144   7.614228
# 12   Q1_89  1910.603996  13        169   7.555175
# 13   Q2_89  2331.164993  14        196   7.754123
# 14   Q3_89  2206.549995  15        225   7.699185
# 15   Q4_89  2173.967995  16        256   7.684309
# 16   Q1_90  2148.278000  17        289   7.672422
# 17   Q2_90  2739.307999  18        324   7.915461
# ...

# %%
quarter =['Jan','Apr','Jul','Oct',] 
import numpy as np
p = df["Quarter"][0]
p[0:3]
df['quarter']= 0

for i in range(42):
    p = df["Quarter"][i]
    df['quarter'][i]= p[0:3]
# Out:
# <ipython-input-6-4122c8b6be0d>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quarter'][i]= p[0:3]
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df
# Out:
#    Quarter        Sales   t  t_squared  log_Sales quarter
# 0    Q1_86  1734.827000   1          1   7.458663     Q1_
# 1    Q2_86  2244.960999   2          4   7.716443     Q2_
# 2    Q3_86  2533.804993   3          9   7.837477     Q3_
# 3    Q4_86  2154.962997   4         16   7.675529     Q4_
# 4    Q1_87  1547.818996   5         25   7.344602     Q1_
# 5    Q2_87  2104.411995   6         36   7.651791     Q2_
# 6    Q3_87  2014.362999   7         49   7.608058     Q3_
# 7    Q4_87  1991.746998   8         64   7.596767     Q4_
# 8    Q1_88  1869.049999   9         81   7.533186     Q1_
# 9    Q2_88  2313.631996  10        100   7.746574     Q2_
# 10   Q3_88  2128.320000  11        121   7.663088     Q3_
# 11   Q4_88  2026.828999  12        144   7.614228     Q4_
# 12   Q1_89  1910.603996  13        169   7.555175     Q1_
# 13   Q2_89  2331.164993  14        196   7.754123     Q2_
# 14   Q3_89  2206.549995  15        225   7.699185     Q3_
# ...

# %%
quarter_dummies = pd.DataFrame(pd.get_dummies(df['quarter']))
cola = pd.concat([df,quarter_dummies],axis = 1)

# %%
cola
# Out:
#    Quarter        Sales   t  t_squared  log_Sales quarter  Q1_  Q2_  Q3_  Q4_
# 0    Q1_86  1734.827000   1          1   7.458663     Q1_    1    0    0    0
# 1    Q2_86  2244.960999   2          4   7.716443     Q2_    0    1    0    0
# 2    Q3_86  2533.804993   3          9   7.837477     Q3_    0    0    1    0
# 3    Q4_86  2154.962997   4         16   7.675529     Q4_    0    0    0    1
# 4    Q1_87  1547.818996   5         25   7.344602     Q1_    1    0    0    0
# 5    Q2_87  2104.411995   6         36   7.651791     Q2_    0    1    0    0
# 6    Q3_87  2014.362999   7         49   7.608058     Q3_    0    0    1    0
# 7    Q4_87  1991.746998   8         64   7.596767     Q4_    0    0    0    1
# 8    Q1_88  1869.049999   9         81   7.533186     Q1_    1    0    0    0
# 9    Q2_88  2313.631996  10        100   7.746574     Q2_    0    1    0    0
# 10   Q3_88  2128.320000  11        121   7.663088     Q3_    0    0    1    0
# ...

# %%
cola["Date"] = pd.to_datetime(df['Quarter'].str[-2:]+df['Quarter'].str[:2])
cola["quarter"] = cola.Date.dt.strftime("%b") 
cola["year"] = cola.Date.dt.strftime("%Y") # year extraction

# %%
cola
# Out:
#    Quarter        Sales   t  t_squared  log_Sales quarter  Q1_  Q2_  Q3_  Q4_  \
# 0    Q1_86  1734.827000   1          1   7.458663     Jan    1    0    0    0
# 1    Q2_86  2244.960999   2          4   7.716443     Apr    0    1    0    0
# 2    Q3_86  2533.804993   3          9   7.837477     Jul    0    0    1    0
# 3    Q4_86  2154.962997   4         16   7.675529     Oct    0    0    0    1
# 4    Q1_87  1547.818996   5         25   7.344602     Jan    1    0    0    0
# 5    Q2_87  2104.411995   6         36   7.651791     Apr    0    1    0    0
# 6    Q3_87  2014.362999   7         49   7.608058     Jul    0    0    1    0
# 7    Q4_87  1991.746998   8         64   7.596767     Oct    0    0    0    1
# 8    Q1_88  1869.049999   9         81   7.533186     Jan    1    0    0    0
# 9    Q2_88  2313.631996  10        100   7.746574     Apr    0    1    0    0
# 10   Q3_88  2128.320000  11        121   7.663088     Jul    0    0    1    0
# ...

# %%
cola = cola.rename({'Q1_':'Jan','Q2_':'Apr','Q3_':'Jul','Q4_':'Oct'},axis=1)
cola
# Out:
#    Quarter        Sales   t  t_squared  log_Sales quarter  Jan  Apr  Jul  Oct  \
# 0    Q1_86  1734.827000   1          1   7.458663     Jan    1    0    0    0
# 1    Q2_86  2244.960999   2          4   7.716443     Apr    0    1    0    0
# 2    Q3_86  2533.804993   3          9   7.837477     Jul    0    0    1    0
# 3    Q4_86  2154.962997   4         16   7.675529     Oct    0    0    0    1
# 4    Q1_87  1547.818996   5         25   7.344602     Jan    1    0    0    0
# 5    Q2_87  2104.411995   6         36   7.651791     Apr    0    1    0    0
# 6    Q3_87  2014.362999   7         49   7.608058     Jul    0    0    1    0
# 7    Q4_87  1991.746998   8         64   7.596767     Oct    0    0    0    1
# 8    Q1_88  1869.049999   9         81   7.533186     Jan    1    0    0    0
# 9    Q2_88  2313.631996  10        100   7.746574     Apr    0    1    0    0
# 10   Q3_88  2128.320000  11        121   7.663088     Jul    0    0    1    0
# ...

# %% [markdown]
# # Upsampling Data

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
# Out:
# <ipython-input-13-7ffc1f1d448d>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
series = read_csv("CocaCola_Sales.csv")

# %%
series
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# ...

# %%
series["Date"] = pd.to_datetime(df['Quarter'].str[-2:]+df['Quarter'].str[:2])

# %%
series
# Out:
#    Quarter        Sales       Date
# 0    Q1_86  1734.827000 2086-01-01
# 1    Q2_86  2244.960999 2086-04-01
# 2    Q3_86  2533.804993 2086-07-01
# 3    Q4_86  2154.962997 2086-10-01
# 4    Q1_87  1547.818996 2087-01-01
# 5    Q2_87  2104.411995 2087-04-01
# 6    Q3_87  2014.362999 2087-07-01
# 7    Q4_87  1991.746998 2087-10-01
# 8    Q1_88  1869.049999 2088-01-01
# 9    Q2_88  2313.631996 2088-04-01
# 10   Q3_88  2128.320000 2088-07-01
# 11   Q4_88  2026.828999 2088-10-01
# 12   Q1_89  1910.603996 2089-01-01
# 13   Q2_89  2331.164993 2089-04-01
# 14   Q3_89  2206.549995 2089-07-01
# 15   Q4_89  2173.967995 2089-10-01
# 16   Q1_90  2148.278000 2090-01-01
# 17   Q2_90  2739.307999 2090-04-01
# 18   Q3_90  2792.753998 2090-07-01
# 19   Q4_90  2556.009995 2090-10-01
# 20   Q1_91  2480.973999 2091-01-01
# 21   Q2_91  3039.522995 2091-04-01
# 22   Q3_91  3172.115997 2091-07-01
# 23   Q4_91  2879.000999 2091-10-01
# 24   Q1_92  2772.000000 2092-01-01
# 25   Q2_92  3550.000000 2092-04-01
# ...

# %%
series = series.drop({'Quarter'},axis=1)
series
# Out:
#           Sales       Date
# 0   1734.827000 2086-01-01
# 1   2244.960999 2086-04-01
# 2   2533.804993 2086-07-01
# 3   2154.962997 2086-10-01
# 4   1547.818996 2087-01-01
# 5   2104.411995 2087-04-01
# 6   2014.362999 2087-07-01
# 7   1991.746998 2087-10-01
# 8   1869.049999 2088-01-01
# 9   2313.631996 2088-04-01
# 10  2128.320000 2088-07-01
# 11  2026.828999 2088-10-01
# 12  1910.603996 2089-01-01
# 13  2331.164993 2089-04-01
# 14  2206.549995 2089-07-01
# 15  2173.967995 2089-10-01
# 16  2148.278000 2090-01-01
# 17  2739.307999 2090-04-01
# 18  2792.753998 2090-07-01
# 19  2556.009995 2090-10-01
# 20  2480.973999 2091-01-01
# 21  3039.522995 2091-04-01
# 22  3172.115997 2091-07-01
# 23  2879.000999 2091-10-01
# 24  2772.000000 2092-01-01
# 25  3550.000000 2092-04-01
# 26  3508.000000 2092-07-01
# 27  3243.859993 2092-10-01
# 28  3056.000000 2093-01-01
# 29  3899.000000 2093-04-01
# 30  3629.000000 2093-07-01
# 31  3373.000000 2093-10-01
# 32  3352.000000 2094-01-01
# ...

# %%
series = series.set_index("Date")
series
# Out:
#                   Sales
# Date
# 2086-01-01  1734.827000
# 2086-04-01  2244.960999
# 2086-07-01  2533.804993
# 2086-10-01  2154.962997
# 2087-01-01  1547.818996
# 2087-04-01  2104.411995
# 2087-07-01  2014.362999
# 2087-10-01  1991.746998
# 2088-01-01  1869.049999
# 2088-04-01  2313.631996
# 2088-07-01  2128.320000
# 2088-10-01  2026.828999
# 2089-01-01  1910.603996
# 2089-04-01  2331.164993
# 2089-07-01  2206.549995
# 2089-10-01  2173.967995
# 2090-01-01  2148.278000
# 2090-04-01  2739.307999
# 2090-07-01  2792.753998
# 2090-10-01  2556.009995
# 2091-01-01  2480.973999
# 2091-04-01  3039.522995
# 2091-07-01  3172.115997
# 2091-10-01  2879.000999
# 2092-01-01  2772.000000
# 2092-04-01  3550.000000
# 2092-07-01  3508.000000
# 2092-10-01  3243.859993
# 2093-01-01  3056.000000
# 2093-04-01  3899.000000
# 2093-07-01  3629.000000
# 2093-10-01  3373.000000
# 2094-01-01  3352.000000
# 2094-04-01  4342.000000
# 2094-07-01  4461.000000
# 2094-10-01  4017.000000
# 2095-01-01  3854.000000
# ...

# %%
upsampled = series.resample('D').mean()
print(upsampled.head(32))
# Out:
#                Sales
# Date
# 2086-01-01  1734.827
# 2086-01-02       NaN
# 2086-01-03       NaN
# 2086-01-04       NaN
# 2086-01-05       NaN
# 2086-01-06       NaN
# 2086-01-07       NaN
# 2086-01-08       NaN
# 2086-01-09       NaN
# 2086-01-10       NaN
# 2086-01-11       NaN
# 2086-01-12       NaN
# 2086-01-13       NaN
# 2086-01-14       NaN
# 2086-01-15       NaN
# 2086-01-16       NaN
# 2086-01-17       NaN
# 2086-01-18       NaN
# 2086-01-19       NaN
# 2086-01-20       NaN
# 2086-01-21       NaN
# 2086-01-22       NaN
# 2086-01-23       NaN
# 2086-01-24       NaN
# 2086-01-25       NaN
# 2086-01-26       NaN
# 2086-01-27       NaN
# 2086-01-28       NaN
# 2086-01-29       NaN
# 2086-01-30       NaN
# 2086-01-31       NaN
# 2086-02-01       NaN

# %% [markdown]
# # interpolate the missing value

# %%
interpolated = upsampled.interpolate(method='linear')
print(interpolated.head(32))
interpolated.plot()
pyplot.show()
# Out:
#                   Sales
# Date
# 2086-01-01  1734.827000
# 2086-01-02  1740.495156
# 2086-01-03  1746.163311
# 2086-01-04  1751.831467
# 2086-01-05  1757.499622
# 2086-01-06  1763.167778
# 2086-01-07  1768.835933
# 2086-01-08  1774.504089
# 2086-01-09  1780.172244
# 2086-01-10  1785.840400
# 2086-01-11  1791.508555
# 2086-01-12  1797.176711
# 2086-01-13  1802.844867
# 2086-01-14  1808.513022
# 2086-01-15  1814.181178
# 2086-01-16  1819.849333
# 2086-01-17  1825.517489
# 2086-01-18  1831.185644
# 2086-01-19  1836.853800
# 2086-01-20  1842.521955
# 2086-01-21  1848.190111
# 2086-01-22  1853.858266
# 2086-01-23  1859.526422
# 2086-01-24  1865.194578
# 2086-01-25  1870.862733
# 2086-01-26  1876.530889
# 2086-01-27  1882.199044
# 2086-01-28  1887.867200
# 2086-01-29  1893.535355
# 2086-01-30  1899.203511
# 2086-01-31  1904.871666
# 2086-02-01  1910.539822

# %% [markdown]
# # Downsampling Data

# %%
# downsample to quarterly intervals
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
# Out:
# <ipython-input-22-fc207076a1de>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
resample = series.resample('Q')
quarterly_mean_sales = resample.mean()

# %% [markdown]
# # Tranformations

# %%
# load and plot a time series
from pandas import read_csv
from matplotlib import pyplot
import numpy as np

# %%
series
# Out:
#                   Sales
# Date
# 2086-01-01  1734.827000
# 2086-04-01  2244.960999
# 2086-07-01  2533.804993
# 2086-10-01  2154.962997
# 2087-01-01  1547.818996
# 2087-04-01  2104.411995
# 2087-07-01  2014.362999
# 2087-10-01  1991.746998
# 2088-01-01  1869.049999
# 2088-04-01  2313.631996
# 2088-07-01  2128.320000
# 2088-10-01  2026.828999
# 2089-01-01  1910.603996
# 2089-04-01  2331.164993
# 2089-07-01  2206.549995
# 2089-10-01  2173.967995
# 2090-01-01  2148.278000
# 2090-04-01  2739.307999
# 2090-07-01  2792.753998
# 2090-10-01  2556.009995
# 2091-01-01  2480.973999
# 2091-04-01  3039.522995
# 2091-07-01  3172.115997
# 2091-10-01  2879.000999
# 2092-01-01  2772.000000
# 2092-04-01  3550.000000
# 2092-07-01  3508.000000
# 2092-10-01  3243.859993
# 2093-01-01  3056.000000
# 2093-04-01  3899.000000
# 2093-07-01  3629.000000
# 2093-10-01  3373.000000
# 2094-01-01  3352.000000
# 2094-04-01  4342.000000
# 2094-07-01  4461.000000
# 2094-10-01  4017.000000
# 2095-01-01  3854.000000
# ...

# %%
# line plot
pyplot.subplot(211)
pyplot.plot(series)
# histogram
pyplot.subplot(212)
pyplot.hist(series)
pyplot.show()

# %% [markdown]
# # Square Root Transform

# %%
from pandas import read_csv
from pandas import DataFrame
from numpy import sqrt
from matplotlib import pyplot

# %%
dataframe = DataFrame(series.values)
dataframe.columns = ['Sales']
dataframe['Sales'] = sqrt(dataframe['Sales'])

# %%
# line plot
pyplot.subplot(211)
pyplot.plot(dataframe['Sales'])
# histogram
pyplot.subplot(212)
pyplot.hist(dataframe['Sales'])
pyplot.show()

# %% [markdown]
# # Log Transform

# %%
from numpy import log
dataframe = DataFrame(series.values)
dataframe.columns = ['Sales']
dataframe['Sales'] = log(dataframe['Sales'])

# line plot
pyplot.subplot(211)
pyplot.plot(dataframe['Sales'])
# histogram
pyplot.subplot(212)
pyplot.hist(dataframe['Sales'])
pyplot.show()

# %%
print(quarterly_mean_sales.head())
quarterly_mean_sales.plot()
pyplot.show()
# Out:
#                   Sales
# Date
# 2086-03-31  1734.827000
# 2086-06-30  2244.960999
# 2086-09-30  2533.804993
# 2086-12-31  2154.962997
# 2087-03-31  1547.818996

# %% [markdown]
# # Model based methods

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
heatmap_y_month = pd.pivot_table(data=cola,values="Sales",index="year",columns="quarter",aggfunc="mean",fill_value=0)
sns.heatmap(heatmap_y_month,annot=True,fmt="g") #fmt is format of the grid values
# Out:
# <AxesSubplot:xlabel='quarter', ylabel='year'>

# %%
# Boxplot for ever
plt.figure(figsize=(8,6))
plt.subplot(211)
sns.boxplot(x="quarter",y="Sales",data=cola)
plt.subplot(212)
sns.boxplot(x="year",y="Sales",data=cola)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Sales'>

# %%
plt.figure(figsize=(12,3))
sns.lineplot(x="year",y="Sales",data=cola)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Sales'>

# %% [markdown]
# # Splitting data

# %%
Train = cola.head(36)
Test = cola.tail(5)

# %%
#Linear Model
import statsmodels.formula.api as smf 

linear_model = smf.ols('Sales~t',data=Train).fit()
pred_linear =  pd.Series(linear_model.predict(pd.DataFrame(Test['t'])))
rmse_linear = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_linear))**2))
rmse_linear
# Out:
# 730.4625620512882

# %%
#Exponential

Exp = smf.ols('log_Sales~t',data=Train).fit()
pred_Exp = pd.Series(Exp.predict(pd.DataFrame(Test['t'])))
rmse_Exp = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(pred_Exp)))**2))
rmse_Exp
# Out:
# 570.654284147593

# %%
#Quadratic 

Quad = smf.ols('Sales~t+t_squared',data=Train).fit()
pred_Quad = pd.Series(Quad.predict(Test[["t","t_squared"]]))
rmse_Quad = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_Quad))**2))
rmse_Quad
# Out:
# 471.05726321177286

# %%
#Additive seasonality 

add_sea = smf.ols('Sales~Jan+Apr+Jul+Oct',data=Train).fit()
pred_add_sea = pd.Series(add_sea.predict(Test[['Jan','Apr','Jul','Oct',]]))
rmse_add_sea = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_add_sea))**2))
rmse_add_sea
# Out:
# 1959.7364080599712

# %%
#Additive Seasonality Quadratic 

add_sea_Quad = smf.ols('Sales~t+t_squared+Jan+Apr+Jul+Oct',data=Train).fit()
pred_add_sea_quad = pd.Series(add_sea_Quad.predict(Test[['Jan','Apr','Jul','Oct','t','t_squared']]))
rmse_add_sea_quad = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_add_sea_quad))**2))
rmse_add_sea_quad
# Out:
# 293.05037387224894

# %%
##Multiplicative Seasonality

Mul_sea = smf.ols('log_Sales~Jan+Apr+Jul+Oct',data = Train).fit()
pred_Mult_sea = pd.Series(Mul_sea.predict(Test))
rmse_Mult_sea = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(pred_Mult_sea)))**2))
rmse_Mult_sea
# Out:
# 2046.8346532958765

# %%
#Multiplicative Additive Seasonality 

Mul_Add_sea = smf.ols('log_Sales~t+Jan+Apr+Jul+Oct',data = Train).fit()
pred_Mult_add_sea = pd.Series(Mul_Add_sea.predict(Test))
rmse_Mult_add_sea = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(pred_Mult_add_sea)))**2))
rmse_Mult_add_sea
# Out:
# 327.3714675621775

# %%
#Compare the results 

data = {"MODEL":pd.Series(["rmse_linear","rmse_Exp","rmse_Quad","rmse_add_sea","rmse_add_sea_quad","rmse_Mult_sea","rmse_Mult_add_sea"]),"RMSE_Values":pd.Series([rmse_linear,rmse_Exp,rmse_Quad,rmse_add_sea,rmse_add_sea_quad,rmse_Mult_sea,rmse_Mult_add_sea])}
table_rmse=pd.DataFrame(data)
table_rmse.sort_values(['RMSE_Values'])
# Out:
#                MODEL  RMSE_Values
# 4  rmse_add_sea_quad   293.050374
# 6  rmse_Mult_add_sea   327.371468
# 2          rmse_Quad   471.057263
# 1           rmse_Exp   570.654284
# 0        rmse_linear   730.462562
# 3       rmse_add_sea  1959.736408
# 5      rmse_Mult_sea  2046.834653

# %% [markdown]
# # Predict for new time period

# %%
pred_file = pd.read_csv("C:\\Users\\DELL\\Desktop\\pred_file.csv")
pred_file
# Out:
#   Quarter
# 0   Q3_96
# 1   Q4_96
# 2   Q1_97
# 3   Q2_97
# 4   Q3_97
# 5   Q4_97

# %%
t = np.arange(43,49)
t
# Out:
# array([43, 44, 45, 46, 47, 48])

# %%
t_squared = t*t
t_squared
# Out:
# array([1849, 1936, 2025, 2116, 2209, 2304])

# %%
df = {'t':t ,'t_squared':t_squared}
value = pd.DataFrame(df)
value
# Out:
#     t  t_squared
# 0  43       1849
# 1  44       1936
# 2  45       2025
# 3  46       2116
# 4  47       2209
# 5  48       2304

# %%
quarter = pd.date_range(start = '7/1/2096',periods =6,freq = '3MS')
quarter
# Out:
# DatetimeIndex(['2096-07-01', '2096-10-01', '2097-01-01', '2097-04-01',
#                '2097-07-01', '2097-10-01'],
#               dtype='datetime64[ns]', freq='3MS')

# %%
Quarter = pd.DataFrame(quarter,columns = ['quarter'])
Quarter
# Out:
#      quarter
# 0 2096-07-01
# 1 2096-10-01
# 2 2097-01-01
# 3 2097-04-01
# 4 2097-07-01
# 5 2097-10-01

# %%
pred_file = pd.concat([Quarter,value],axis=1)
pred_file
# Out:
#      quarter   t  t_squared
# 0 2096-07-01  43       1849
# 1 2096-10-01  44       1936
# 2 2097-01-01  45       2025
# 3 2097-04-01  46       2116
# 4 2097-07-01  47       2209
# 5 2097-10-01  48       2304

# %%
pred_file["Date"] = pd.to_datetime(pred_file.quarter,format = "%b-%y")
pred_file["quarter"] = pred_file.Date.dt.strftime("%b") # month extraction
pred_file["year"] = pred_file.Date.dt.strftime("%Y") # year extraction

# %%
pred_file
# Out:
#   quarter   t  t_squared       Date  year
# 0     Jul  43       1849 2096-07-01  2096
# 1     Oct  44       1936 2096-10-01  2096
# 2     Jan  45       2025 2097-01-01  2097
# 3     Apr  46       2116 2097-04-01  2097
# 4     Jul  47       2209 2097-07-01  2097
# 5     Oct  48       2304 2097-10-01  2097

# %%
quarter_dummies = pd.DataFrame(pd.get_dummies(pred_file['quarter']))
final_data = pd.concat([pred_file,quarter_dummies],axis = 1)
final_data
# Out:
#   quarter   t  t_squared       Date  year  Apr  Jan  Jul  Oct
# 0     Jul  43       1849 2096-07-01  2096    0    0    1    0
# 1     Oct  44       1936 2096-10-01  2096    0    0    0    1
# 2     Jan  45       2025 2097-01-01  2097    0    1    0    0
# 3     Apr  46       2116 2097-04-01  2097    1    0    0    0
# 4     Jul  47       2209 2097-07-01  2097    0    0    1    0
# 5     Oct  48       2304 2097-10-01  2097    0    0    0    1

# %%
quarter_dummies
# Out:
#    Apr  Jan  Jul  Oct
# 0    0    0    1    0
# 1    0    0    0    1
# 2    0    1    0    0
# 3    1    0    0    0
# 4    0    0    1    0
# 5    0    0    0    1

# %%
final_data = pd.concat([pred_file,quarter_dummies],axis=1)
final_data
# Out:
#   quarter   t  t_squared       Date  year  Apr  Jan  Jul  Oct
# 0     Jul  43       1849 2096-07-01  2096    0    0    1    0
# 1     Oct  44       1936 2096-10-01  2096    0    0    0    1
# 2     Jan  45       2025 2097-01-01  2097    0    1    0    0
# 3     Apr  46       2116 2097-04-01  2097    1    0    0    0
# 4     Jul  47       2209 2097-07-01  2097    0    0    1    0
# 5     Oct  48       2304 2097-10-01  2097    0    0    0    1

# %% [markdown]
# # Build the model on entire data set

# %%
#Additive Seasonality Quadratic 

add_sea_Quad = smf.ols('Sales~t+t_squared+Jan+Apr+Jul+Oct', data = cola).fit()
pred_add_sea_quad = pd.Series(add_sea_Quad.predict(Test[['Jan','Apr','Jul','Oct','t','t_squared']]))
rmse_add_sea_quad = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_add_sea_quad))**2))
rmse_add_sea_quad
# Out:
# 201.3551039213632

# %%
pred_file  = pd.Series(add_sea_Quad.predict(final_data))
pred_file
# Out:
# 0    5319.754557
# 1    5137.955882
# 2    5069.668337
# 3    5866.186600
# 4    5942.178733
# 5    5774.444481
# dtype: float64

# %%
final_data["forecasted_sales"] = pd.Series(pred_file)
final_data
# Out:
#   quarter   t  t_squared       Date  year  Apr  Jan  Jul  Oct  \
# 0     Jul  43       1849 2096-07-01  2096    0    0    1    0
# 1     Oct  44       1936 2096-10-01  2096    0    0    0    1
# 2     Jan  45       2025 2097-01-01  2097    0    1    0    0
# 3     Apr  46       2116 2097-04-01  2097    1    0    0    0
# 4     Jul  47       2209 2097-07-01  2097    0    0    1    0
# 5     Oct  48       2304 2097-10-01  2097    0    0    0    1
#
#    forecasted_sales
# 0       5319.754557
# 1       5137.955882
# 2       5069.668337
# 3       5866.186600
# 4       5942.178733
# 5       5774.444481

# %% [markdown]
# # Data Driven Models

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing # SES
from statsmodels.tsa.holtwinters import Holt # Holts Exponential Smoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %% [markdown]
# # Splitting data

# %%
Train = cola.head(36)
Test = cola.tail(5)

# %% [markdown]
# # Moving Average

# %%
plt.figure(figsize=(12,4))
cola.Sales.plot(label="org")
for i in range(2,24,6):
    cola["Sales"].rolling(i).mean().plot(label=str(i))
plt.legend(loc='best')

# %%
##Time series decomposition plot
decompose_ts_add = seasonal_decompose(cola.Sales,period=12)
decompose_ts_add.plot()
plt.show()

# %% [markdown]
# # ACF plots and PACF plots

# %%
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf(cola.Sales,lags=12)
tsa_plots.plot_pacf(cola.Sales,lags=12)
plt.show()

# %% [markdown]
# # Evaluation Metric MAPE

# %%
def MAPE(pred,org):
    temp = np.abs((pred-org)/org)*100
    return np.mean(temp)

# %% [markdown]
# # simple Exponential Method

# %%
ses_model = SimpleExpSmoothing(Train["Sales"]).fit(smoothing_level=0.2)
pred_ses = ses_model.predict(start = Test.index[0],end = Test.index[-1])
MAPE(pred_ses,Test.Sales)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# 19.460039459271783

# %% [markdown]
# # Holt method

# %%
# Holt method 
hw_model = Holt(Train["Sales"]).fit(smoothing_level=0.8, smoothing_slope=0.2)
pred_hw = hw_model.predict(start = Test.index[0],end = Test.index[-1])
MAPE(pred_hw,Test.Sales)
# Out:
# <ipython-input-67-baaa29c0f6b9>:2: FutureWarning: the 'smoothing_slope'' keyword is deprecated, use 'smoothing_trend' instead
#   hw_model = Holt(Train["Sales"]).fit(smoothing_level=0.8, smoothing_slope=0.2)
# 9.326570650235457

# %%
#Holts winter exponential smoothing with additive seasonality and additive trend
hwe_model_add_add = ExponentialSmoothing(Train["Sales"],seasonal="add",trend="add",seasonal_periods=12).fit() #add the trend to the model
pred_hwe_add_add = hwe_model_add_add.predict(start = Test.index[0],end = Test.index[-1])
MAPE(pred_hwe_add_add,Test.Sales)
# Out:
# 5.275171684062679

# %%
#Holts winter exponential smoothing with multiplicative seasonality and additive trend
hwe_model_mul_add = ExponentialSmoothing(Train["Sales"],seasonal="mul",trend="add",seasonal_periods=12).fit() 
pred_hwe_mul_add = hwe_model_mul_add.predict(start = Test.index[0],end = Test.index[-1])
MAPE(pred_hwe_mul_add,Test.Sales)
# Out:
# 2.7653584161319187

# %% [markdown]
# # Final Model by combining train and test

# %%
hwe_model_add_add = ExponentialSmoothing(cola["Sales"],seasonal="add",trend="add",seasonal_periods=12).fit()

# %%
#Forecasting for next 10 time periods
hwe_model_add_add.forecast(10)
# Out:
# 42    4942.584816
# 43    4768.873862
# 44    4810.433521
# 45    5675.016330
# 46    5693.607765
# 47    5278.474316
# 48    5177.096543
# 49    6123.344808
# 50    5994.481454
# 51    5554.121536
# dtype: float64

# %% [markdown]
# # Arima model Forecasting

# %%
# Import libraries
from pandas import read_csv
from matplotlib import pyplot
from numpy import sqrt
import warnings
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
series
# Out:
#                Sales
# Date
# 2086-01-01  3.729331
# 2086-04-01  3.858222
# 2086-07-01  3.918739
# 2086-10-01  3.837764
# 2087-01-01  3.672301
# 2087-04-01  3.825896
# 2087-07-01  3.804029
# 2087-10-01  3.798384
# 2088-01-01  3.766593
# 2088-04-01  3.873287
# 2088-07-01  3.831544
# 2088-10-01  3.807114
# 2089-01-01  3.777587
# 2089-04-01  3.877062
# 2089-07-01  3.849593
# 2089-10-01  3.842155
# 2090-01-01  3.836211
# 2090-04-01  3.957730
# 2090-07-01  3.967392
# 2090-10-01  3.923101
# 2091-01-01  3.908203
# 2091-04-01  4.009728
# 2091-07-01  4.031077
# 2091-10-01  3.982599
# 2092-01-01  3.963662
# 2092-04-01  4.087351
# 2092-07-01  4.081401
# 2092-10-01  4.042260
# 2093-01-01  4.012431
# 2093-04-01  4.134238
# 2093-07-01  4.098356
# 2093-10-01  4.061779
# 2094-01-01  4.058656
# 2094-04-01  4.188045
# 2094-07-01  4.201564
# 2094-10-01  4.149145
# 2095-01-01  4.128433
# 2095-04-01  4.252155
# 2095-07-01  4.247985
# 2095-10-01  4.187008
# 2096-01-01  4.170705
# 2096-04-01  4.283277

# %%
# line plot of time series
from pandas import read_csv
from matplotlib import pyplot
series.plot()
pyplot.show()

# %%
series.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Sales'}>]], dtype=object)

# %%
series.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# separate out a validation dataset
split_point = len(series) - 10
dataset, validation = series[0:split_point], series[split_point:]
print('Dataset %d, Validation %d' % (len(dataset), len(validation)))
dataset.to_csv('dataset.csv', header=False)
validation.to_csv('validation.csv', header=False)
# Out:
# Dataset 32, Validation 10

# %% [markdown]
# # Persistence/ Base model

# %%
# evaluate a persistence model
from pandas import read_csv
from sklearn.metrics import mean_squared_error
from math import sqrt
# load data
train = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True)
# prepare data
X = train.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]

# %%
# walk-forward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
    yhat = history[-1]
    predictions.append(yhat)
# observation
    obs = test[i]
    history.append(obs)
    print('>Predicted=%.3f, Expected=%.3f' % (yhat, obs))
# report performance
rmse = sqrt(mean_squared_error(test, predictions))
print('RMSE: %.3f' % rmse)
# Out:
# >Predicted=3.842, Expected=3.836
# >Predicted=3.836, Expected=3.958
# >Predicted=3.958, Expected=3.967
# >Predicted=3.967, Expected=3.923
# >Predicted=3.923, Expected=3.908
# >Predicted=3.908, Expected=4.010
# >Predicted=4.010, Expected=4.031
# >Predicted=4.031, Expected=3.983
# >Predicted=3.983, Expected=3.964
# >Predicted=3.964, Expected=4.087
# >Predicted=4.087, Expected=4.081
# >Predicted=4.081, Expected=4.042
# >Predicted=4.042, Expected=4.012
# >Predicted=4.012, Expected=4.134
# >Predicted=4.134, Expected=4.098
# >Predicted=4.098, Expected=4.062
# RMSE: 0.064

# %% [markdown]
# # ARIMA Hyperparameters

# %%
# grid search ARIMA parameters for a time series

import warnings
from pandas import read_csv
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt


# evaluate an ARIMA model for a given order (p,d,q) and return RMSE
def evaluate_arima_model(X, arima_order):
# prepare training dataset
    X = X.astype('float32')
    train_size = int(len(X) * 0.50)
    train, test = X[0:train_size], X[train_size:]
    history = [x for x in train]
# make predictions
    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=arima_order)
# model_fit = model.fit(disp=0)
        model_fit = model.fit(disp=0)
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(test[t])
# calculate out of sample error
    rmse = sqrt(mean_squared_error(test, predictions))
    return rmse

# %% [markdown]
# # Grid search for p,d,q values

# %%
# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
    dataset = dataset.astype('float32')
    best_score, best_cfg = float('inf'), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    rmse = evaluate_arima_model(train, order)
                    if rmse < best_score:
                        best_score, best_cfg = rmse, order
                    print('ARIMA%s RMSE=%.3f' % (order,rmse))
                except:
                    continue
    print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# %%
# load dataset
train = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True)
# evaluate parameters
#p_values = range(0, 5)
#d_values = range(0, 5)
#q_values = range(0, 5)
warnings.filterwarnings("ignore")
#evaluate_models(train.values, p_values, d_values, q_values)

# %% [markdown]
# # Build Model based on the optimized values

# %%
# save finalized model to file
from pandas import read_csv
from statsmodels.tsa.arima_model import ARIMA
import numpy

# %%
# load data
train = read_csv('dataset.csv', header=0, index_col=0, parse_dates=True)
# prepare data
X = train.values
X = X.astype('float32')

# %%
# fit model
model = ARIMA(X, order=(3,1,0))
model_fit = model.fit()
forecast=model_fit.forecast(steps=10)[0]
model_fit.plot_predict(1, 30)

# %%
#Error on the test data
val=pd.read_csv('validation.csv',header=None)
rmse = sqrt(mean_squared_error(val[1], forecast))
rmse
# Out:
# 0.05298217313759481

# %% [markdown]
# # Combine train and test data and build final model

# %%
# fit model
data = read_csv('Airlines_Data.csv', header=0, index_col=0, parse_dates=True)
# prepare data
X = train.values
X = X.astype('float32')

# %%
model = ARIMA(X, order=(3,1,0))
model_fit = model.fit()

# %%
forecast=model_fit.forecast(steps=10)[0]
model_fit.plot_predict(1,30)

# %%
forecast
# Out:
# array([4.05850514, 4.14937333, 4.14242681, 4.10520508, 4.10152581,
#        4.1714878 , 4.18103124, 4.14919956, 4.14343576, 4.19806877])
